# %%
import numpy as np
import pandas as pd

# %%
def ganador(row):
  if row['Goles Local'] > row['Goles Visitante']:
    return row['Equipo Local']
  elif row['Goles Local'] < row['Goles Visitante']:
    return row['Equipo Visitante']
  else:
    return 'Empate'

# %%
df=pd.read_csv('Premier_League_20xx.csv')
df.drop(['promedio_asistencia_x'],axis=1,inplace=True)
df.drop(['promedio_asistencia_y'],axis=1,inplace=True)
df['Codigo'] = pd.factorize(df['Equipo Local'])[0] + 1  # Sumar 1 para que los códigos empiecen en 1
df['Ganador'] = df.apply(ganador, axis=1)
df.rename(columns={'Tiros Visitante Local':'Tiros Visitante Total'}, inplace=True)

df['fecha_formato']=pd.to_datetime(df['fecha_formato'])

# %%
df_local = df[['Fecha', 'Reloj', 'Estadio', 'Asistencia', 'Equipo Local','Equipo Visitante',
                'Goles Local', 'Goles Visitante', 'Posesión Local', 'Posesión Visitante', 'Tiros Locales Total', 'Tiros Visitante Total',
                'Tiros A Puerta Local', 'Tiros A Puerta Visitante', 'Tiros Fuera de Objetivo Local', 'Tiros Fuera de Objetivo Visitante',
                'Tiros Bloqueados Local', 'Tiros Bloqueados Visitante', 'Precisión en Pases Local', 'Precisión en Pases Visitante',
                'Oportunidades Local', 'Oportunidades Visitante' ,'Esquinas Local', 'Esquinas Visitante', 'Fuera de Juego Local', 'Fuera de Juego Visitante',
                'Porcentaje de Tackles Ganados Local', 'Porcentaje de Tackles Ganados Visitante',
                'Porcentaje de Duelo Aéreo Local', 'Porcentaje de Duelo Aéreo Visitante', 'Paradas Local', 'Paradas Visitante',
                'Faltas Cometidas Local', 'Faltas Cometidas Visitante','Amarillas Local', 'Amarillas Visitante', 'Rojas Local', 'Rojas Visitante', 'fecha_formato','Hora',
                'Año', 'Codigo', 'Ganador']].copy()

df_local['Codigo L_V'] = 1 #Codigo para saber si los datos son de juego Local o Visitante

# %%
df_visitante = df[['Fecha', 'Reloj', 'Estadio', 'Asistencia', 'Equipo Visitante', 'Equipo Local',
                    'Goles Visitante', 'Goles Local', 'Posesión Visitante', 'Posesión Local', 'Tiros Visitante Total', 'Tiros Locales Total',
                    'Tiros A Puerta Visitante', 'Tiros A Puerta Local' ,'Tiros Fuera de Objetivo Visitante', 'Tiros Fuera de Objetivo Local',
                    'Tiros Bloqueados Visitante', 'Tiros Bloqueados Local' ,'Precisión en Pases Visitante', 'Precisión en Pases Local',
                    'Oportunidades Visitante', 'Oportunidades Local' , 'Esquinas Visitante', 'Esquinas Local',
                    'Fuera de Juego Visitante', 'Fuera de Juego Local', 'Porcentaje de Tackles Ganados Visitante', 'Porcentaje de Tackles Ganados Local',
                    'Porcentaje de Duelo Aéreo Visitante', 'Porcentaje de Duelo Aéreo Local' ,'Paradas Visitante', 'Paradas Local',
                    'Faltas Cometidas Visitante', 'Faltas Cometidas Local' ,'Amarillas Visitante', 'Amarillas Local', 'Rojas Visitante', 'Rojas Local' , 'fecha_formato','Hora',
                    'Año', 'Codigo', 'Ganador']].copy()

df_visitante['Codigo L_V'] = 0 #Codigo para saber si los datos son de juego Local o Visitante

# %%
df_local = df_local.rename(columns={'Equipo Local': 'Equipo', 'Equipo Visitante': 'Equipo Rival', 'Goles Local': 'Goles',
                                     'Posesión Local': 'Posesión', 'Tiros Locales Total': 'Tiros Totales',
                                     'Tiros A Puerta Local': 'Tiros A Puerta',
                                     'Tiros Fuera de Objetivo Local': 'Tiros Fuera de Objetivo',
                                     'Tiros Bloqueados Local': 'Tiros Bloqueados',
                                     'Precisión en Pases Local': 'Precisión en Pases',
                                     'Oportunidades Local': 'Oportunidades',
                                     'Esquinas Local': 'Esquinas',
                                     'Fuera de Juego Local': 'Fuera de Juego',
                                     'Porcentaje de Tackles Ganados Local': 'Porcentaje de Tackles Ganados',
                                     'Porcentaje de Duelo Aéreo Local': 'Porcentaje de Duelo Aéreo',
                                     'Paradas Local': 'Paradas',
                                     'Faltas Cometidas Local': 'Faltas Cometidas',
                                     'Amarillas Local': 'Amarillas', 'Rojas Local': 'Rojas', 'Goles Visitante':'Goles Rival', 'Posesión Visitante':'Posesión Rival',
                                      'Tiros Visitante Total': 'Tiros Rival Total', 'Tiros A Puerta Visitante':'Tiros A Puerta Rival',
                                      'Tiros Fuera de Objetivo Visitante':'Tiros Fuera de Objetivo Rival', 'Tiros Bloqueados Visitante':'Tiros Bloqueados Rival',
                                     'Precisión en Pases Visitante':'Precisión en Pases Rival', 'Oportunidades Visitante':'Oportunidades Rival','Esquinas Visitante':'Esquinas Rival',
                                     'Fuera de Juego Visitante':'Fuera de Juego Rival', 'Porcentaje de Tackles Ganados Visitante':'Porcentaje de Tackles Ganados Rival',
                                       'Porcentaje de Duelo Aéreo Visitante':'Porcentaje de Duelo Aéreo Rival','Paradas Visitante':'Paradas Rival',
                                      'Faltas Cometidas Visitante':'Faltas Cometidas Rival', 'Amarillas Visitante':'Amarillas Rival','Rojas Visitante':'Rojas Rival'})

# %%
df_visitante = df_visitante.rename(columns={'Equipo Visitante': 'Equipo', 'Equipo Local': 'Equipo Rival','Goles Visitante': 'Goles',
                                             'Posesión Visitante': 'Posesión', 'Tiros Visitante Total': 'Tiros Totales',
                                             'Tiros A Puerta Visitante': 'Tiros A Puerta',
                                             'Tiros Fuera de Objetivo Visitante': 'Tiros Fuera de Objetivo',
                                             'Tiros Bloqueados Visitante': 'Tiros Bloqueados',
                                             'Precisión en Pases Visitante': 'Precisión en Pases',
                                             'Oportunidades Visitante': 'Oportunidades',
                                             'Esquinas Visitante': 'Esquinas',
                                             'Fuera de Juego Visitante': 'Fuera de Juego',
                                             'Porcentaje de Tackles Ganados Visitante': 'Porcentaje de Tackles Ganados',
                                             'Porcentaje de Duelo Aéreo Visitante': 'Porcentaje de Duelo Aéreo',
                                             'Paradas Visitante': 'Paradas',
                                             'Faltas Cometidas Visitante': 'Faltas Cometidas',
                                             'Amarillas Visitante': 'Amarillas', 'Rojas Visitante': 'Rojas','Goles Local':'Goles Rival', 'Posesión Local':'Posesión Rival',
                                              'Tiros Locales Total': 'Tiros Rival Total', 'Tiros A Puerta Local':'Tiros A Puerta Rival',
                                              'Tiros Fuera de Objetivo Local':'Tiros Fuera de Objetivo Rival', 'Tiros Bloqueados Local':'Tiros Bloqueados Rival',
                                              'Precisión en Pases Local':'Precisión en Pases Rival', 'Oportunidades Local':'Oportunidades Rival','Esquinas Local':'Esquinas Rival',
                                              'Fuera de Juego Local':'Fuera de Juego Rival', 'Porcentaje de Tackles Ganados Local':'Porcentaje de Tackles Ganados Rival',
                                              'Porcentaje de Duelo Aéreo Local':'Porcentaje de Duelo Aéreo Rival','Paradas Local':'Paradas Rival',
                                              'Faltas Cometidas Local':'Faltas Cometidas Rival', 'Amarillas Local':'Amarillas Rival','Rojas Local':'Rojas Rival'})

# %%
df_local.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3240 entries, 0 to 3239
# Data columns (total 44 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Fecha                                3240 non-null   object
#  1   Reloj                                3240 non-null   object
#  2   Estadio                              3240 non-null   object
#  3   Asistencia                           3240 non-null   float64
#  4   Equipo                               3240 non-null   object
#  5   Equipo Rival                         3240 non-null   object
#  6   Goles                                3240 non-null   int64
#  7   Goles Rival                          3240 non-null   int64
#  8   Posesión                             3240 non-null   float64
#  9   Posesión Rival                       3240 non-null   float64
#  10  Tiros Totales                        3240 non-null   int64
#  11  Tiros Rival Total                    3240 non-null   int64
#  12  Tiros A Puerta                       3240 non-null   int64
#  13  Tiros A Puerta Rival                 3240 non-null   int64
#  14  Tiros Fuera de Objetivo              3240 non-null   int64
#  15  Tiros Fuera de Objetivo Rival        3240 non-null   int64
#  16  Tiros Bloqueados                     3240 non-null   int64
#  17  Tiros Bloqueados Rival               3240 non-null   int64
#  18  Precisión en Pases                   3240 non-null   float64
#  19  Precisión en Pases Rival             3240 non-null   float64
#  20  Oportunidades                        3240 non-null   int64
#  21  Oportunidades Rival                  3240 non-null   int64
#  22  Esquinas                             3240 non-null   int64
#  23  Esquinas Rival                       3240 non-null   int64
#  24  Fuera de Juego                       3240 non-null   int64
#  25  Fuera de Juego Rival                 3240 non-null   int64
#  26  Porcentaje de Tackles Ganados        3240 non-null   float64
#  27  Porcentaje de Tackles Ganados Rival  3240 non-null   float64
#  28  Porcentaje de Duelo Aéreo            3240 non-null   float64
#  29  Porcentaje de Duelo Aéreo Rival      3240 non-null   float64
#  30  Paradas                              3240 non-null   int64
#  31  Paradas Rival                        3240 non-null   int64
#  32  Faltas Cometidas                     3240 non-null   int64
#  33  Faltas Cometidas Rival               3240 non-null   int64
#  34  Amarillas                            3240 non-null   int64
#  35  Amarillas Rival                      3240 non-null   int64
#  36  Rojas                                3240 non-null   int64
#  37  Rojas Rival                          3240 non-null   int64
#  38  fecha_formato                        3240 non-null   datetime64[ns]
#  39  Hora                                 3240 non-null   object
#  40  Año                                  3240 non-null   int64
#  41  Codigo                               3240 non-null   int64
#  42  Ganador                              3240 non-null   object
#  43  Codigo L_V                           3240 non-null   int64
# dtypes: datetime64[ns](1), float64(9), int64(27), object(7)
# memory usage: 1.1+ MB

# %%
df_visitante.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3240 entries, 0 to 3239
# Data columns (total 44 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Fecha                                3240 non-null   object
#  1   Reloj                                3240 non-null   object
#  2   Estadio                              3240 non-null   object
#  3   Asistencia                           3240 non-null   float64
#  4   Equipo                               3240 non-null   object
#  5   Equipo Rival                         3240 non-null   object
#  6   Goles                                3240 non-null   int64
#  7   Goles Rival                          3240 non-null   int64
#  8   Posesión                             3240 non-null   float64
#  9   Posesión Rival                       3240 non-null   float64
#  10  Tiros Totales                        3240 non-null   int64
#  11  Tiros Rival Total                    3240 non-null   int64
#  12  Tiros A Puerta                       3240 non-null   int64
#  13  Tiros A Puerta Rival                 3240 non-null   int64
#  14  Tiros Fuera de Objetivo              3240 non-null   int64
#  15  Tiros Fuera de Objetivo Rival        3240 non-null   int64
#  16  Tiros Bloqueados                     3240 non-null   int64
#  17  Tiros Bloqueados Rival               3240 non-null   int64
#  18  Precisión en Pases                   3240 non-null   float64
#  19  Precisión en Pases Rival             3240 non-null   float64
#  20  Oportunidades                        3240 non-null   int64
#  21  Oportunidades Rival                  3240 non-null   int64
#  22  Esquinas                             3240 non-null   int64
#  23  Esquinas Rival                       3240 non-null   int64
#  24  Fuera de Juego                       3240 non-null   int64
#  25  Fuera de Juego Rival                 3240 non-null   int64
#  26  Porcentaje de Tackles Ganados        3240 non-null   float64
#  27  Porcentaje de Tackles Ganados Rival  3240 non-null   float64
#  28  Porcentaje de Duelo Aéreo            3240 non-null   float64
#  29  Porcentaje de Duelo Aéreo Rival      3240 non-null   float64
#  30  Paradas                              3240 non-null   int64
#  31  Paradas Rival                        3240 non-null   int64
#  32  Faltas Cometidas                     3240 non-null   int64
#  33  Faltas Cometidas Rival               3240 non-null   int64
#  34  Amarillas                            3240 non-null   int64
#  35  Amarillas Rival                      3240 non-null   int64
#  36  Rojas                                3240 non-null   int64
#  37  Rojas Rival                          3240 non-null   int64
#  38  fecha_formato                        3240 non-null   datetime64[ns]
#  39  Hora                                 3240 non-null   object
#  40  Año                                  3240 non-null   int64
#  41  Codigo                               3240 non-null   int64
#  42  Ganador                              3240 non-null   object
#  43  Codigo L_V                           3240 non-null   int64
# dtypes: datetime64[ns](1), float64(9), int64(27), object(7)
# memory usage: 1.1+ MB

# %%
df_concatenado = pd.concat([df_local, df_visitante], ignore_index=True)
df_concatenado
# Out:
#                           Fecha    Reloj                 Estadio  Asistencia  \
# 0     Saturday 8th August 2015.  12:45pm            Old Trafford     75261.0
# 1     Saturday 8th August 2015.   3:00pm  The King Power Stadium     32242.0
# 2     Saturday 8th August 2015.   3:00pm           Goodison Park     39063.0
# 3     Saturday 8th August 2015.   3:00pm             Carrow Road     27036.0
# 4     Saturday 8th August 2015.   3:00pm        Vitality Stadium     11155.0
# ...                         ...      ...                     ...         ...
# 6475      Sunday 19th May 2024.   4:00pm           Selhurst Park     25191.0
# 6476      Sunday 19th May 2024.   4:00pm          Etihad Stadium     55097.0
# 6477      Sunday 19th May 2024.   4:00pm         Kenilworth Road     12027.0
# 6478      Sunday 19th May 2024.   4:00pm            Amex Stadium     31662.0
# 6479      Sunday 19th May 2024.   4:00pm        Emirates Stadium     60312.0
#
#                  Equipo              Equipo Rival  Goles  Goles Rival  \
# 0     Manchester United         Tottenham Hotspur      1            0
# 1        Leicester City                Sunderland      4            2
# 2               Everton                   Watford      2            2
# 3          Norwich City            Crystal Palace      1            3
# 4           Bournemouth               Aston Villa      0            1
# ...                 ...                       ...    ...          ...
# 6475        Aston Villa            Crystal Palace      0            5
# 6476    West Ham United           Manchester City      1            3
# 6477             Fulham                Luton Town      4            2
# 6478  Manchester United  Brighton and Hove Albion      2            0
# 6479            Everton                   Arsenal      1            2
#
#       Posesión  Posesión Rival  ...  Amarillas  Amarillas Rival  Rojas  \
# 0         50.0            50.0  ...          2                3      0
# 1         44.0            56.0  ...          2                4      0
# 2         66.6            33.4  ...          1                2      0
# 3         62.9            37.1  ...          1                0      0
# 4         58.4            41.6  ...          3                4      0
# ...        ...             ...  ...        ...              ...    ...
# 6475      46.0            54.0  ...          4                1      0
# 6476      28.6            71.4  ...          1                0      0
# 6477      59.6            40.4  ...          4                5      0
# 6478      45.2            54.8  ...          3                1      0
# 6479      30.9            69.1  ...          3                4      0
#
#       Rojas Rival  fecha_formato      Hora   Año  Codigo            Ganador  \
# 0               0     2015-08-08  12:45:00  2015       1  Manchester United
# 1               0     2015-08-08  15:00:00  2015       2     Leicester City
# 2               0     2015-08-08  15:00:00  2015       3             Empate
# 3               0     2015-08-08  15:00:00  2015       4     Crystal Palace
# 4               0     2015-08-08  15:00:00  2015       5        Aston Villa
# ...           ...            ...       ...   ...     ...                ...
# 6475            0     2024-05-19  16:00:00  2024      18     Crystal Palace
# 6476            0     2024-05-19  16:00:00  2024      19    Manchester City
# 6477            0     2024-05-19  16:00:00  2024      33             Fulham
# 6478            0     2024-05-19  16:00:00  2024      24  Manchester United
# 6479            0     2024-05-19  16:00:00  2024       7            Arsenal
#
#       Codigo L_V
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 6475           0
# 6476           0
# 6477           0
# 6478           0
# 6479           0
#
# [6480 rows x 44 columns]

# %%
df_codigos = df_concatenado[['Equipo', 'Codigo']] # Change 'Codigo' to 'Codigo Rival'
df_codigos = df_codigos.drop_duplicates(subset='Equipo')
df_codigos = df_codigos.rename(columns={'Equipo':'Equipo Rival'})

# %%
df_codigos = df_codigos.rename(columns={'Codigo':'Codigo Rival'})

# %%
df_concatenado = df_concatenado.merge(df_codigos, on='Equipo Rival', how='left')

# %%
df_concatenado['Hora']=df_concatenado['Hora'].str.replace(':.+','',regex=True).astype(int)

# %%
df_concatenado['codigo dia']=df_concatenado['fecha_formato'].dt.dayofweek

# %%
df_concatenado.head(5)
# Out:
#                        Fecha    Reloj                 Estadio  Asistencia  \
# 0  Saturday 8th August 2015.  12:45pm            Old Trafford     75261.0
# 1  Saturday 8th August 2015.   3:00pm  The King Power Stadium     32242.0
# 2  Saturday 8th August 2015.   3:00pm           Goodison Park     39063.0
# 3  Saturday 8th August 2015.   3:00pm             Carrow Road     27036.0
# 4  Saturday 8th August 2015.   3:00pm        Vitality Stadium     11155.0
#
#               Equipo       Equipo Rival  Goles  Goles Rival  Posesión  \
# 0  Manchester United  Tottenham Hotspur      1            0      50.0
# 1     Leicester City         Sunderland      4            2      44.0
# 2            Everton            Watford      2            2      66.6
# 3       Norwich City     Crystal Palace      1            3      62.9
# 4        Bournemouth        Aston Villa      0            1      58.4
#
#    Posesión Rival  ...  Rojas  Rojas Rival  fecha_formato  Hora   Año  Codigo  \
# 0            50.0  ...      0            0     2015-08-08    12  2015       1
# 1            56.0  ...      0            0     2015-08-08    15  2015       2
# 2            33.4  ...      0            0     2015-08-08    15  2015       3
# 3            37.1  ...      0            0     2015-08-08    15  2015       4
# 4            41.6  ...      0            0     2015-08-08    15  2015       5
#
#              Ganador  Codigo L_V  Codigo Rival  codigo dia
# 0  Manchester United           1            14           5
# 1     Leicester City           1            17           5
# 2             Empate           1            15           5
# 3     Crystal Palace           1            18           5
# 4        Aston Villa           1            11           5
#
# [5 rows x 46 columns]

# %% [markdown]
# ## MODELO

# %%
df_concatenado['codigo objetivo'] = (df_concatenado['Equipo'] == df_concatenado['Ganador']).astype(int)

# %%
df_concatenado.head(5)
# Out:
#                        Fecha    Reloj                 Estadio  Asistencia  \
# 0  Saturday 8th August 2015.  12:45pm            Old Trafford     75261.0
# 1  Saturday 8th August 2015.   3:00pm  The King Power Stadium     32242.0
# 2  Saturday 8th August 2015.   3:00pm           Goodison Park     39063.0
# 3  Saturday 8th August 2015.   3:00pm             Carrow Road     27036.0
# 4  Saturday 8th August 2015.   3:00pm        Vitality Stadium     11155.0
#
#               Equipo       Equipo Rival  Goles  Goles Rival  Posesión  \
# 0  Manchester United  Tottenham Hotspur      1            0      50.0
# 1     Leicester City         Sunderland      4            2      44.0
# 2            Everton            Watford      2            2      66.6
# 3       Norwich City     Crystal Palace      1            3      62.9
# 4        Bournemouth        Aston Villa      0            1      58.4
#
#    Posesión Rival  ...  Rojas Rival  fecha_formato  Hora   Año  Codigo  \
# 0            50.0  ...            0     2015-08-08    12  2015       1
# 1            56.0  ...            0     2015-08-08    15  2015       2
# 2            33.4  ...            0     2015-08-08    15  2015       3
# 3            37.1  ...            0     2015-08-08    15  2015       4
# 4            41.6  ...            0     2015-08-08    15  2015       5
#
#              Ganador  Codigo L_V  Codigo Rival  codigo dia  codigo objetivo
# 0  Manchester United           1            14           5                1
# 1     Leicester City           1            17           5                1
# 2             Empate           1            15           5                0
# 3     Crystal Palace           1            18           5                0
# 4        Aston Villa           1            11           5                0
#
# [5 rows x 47 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier(n_estimators=100, min_samples_split=100 ,random_state=43)

# %%
train_set = df_concatenado[df_concatenado['Año'] < 2020]
test_set = df_concatenado[df_concatenado['Año'] >= 2020]

# %%
predecir=['Codigo L_V','Codigo Rival','Hora','codigo dia']

# %%
rf.fit(train_set[predecir],train_set['codigo objetivo'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=43)

# %%
prediccion=rf.predict(test_set[predecir])

# %%
from sklearn.metrics import accuracy_score

# %%
exc=accuracy_score(test_set['codigo objetivo'],prediccion)
exc
# Out:
# 0.6175778953556731

# %%
combinacion=pd.DataFrame(dict(actual=test_set['codigo objetivo'],prediction=prediccion))

# %%
pd.crosstab(index=combinacion['actual'],columns=combinacion['prediction'])
# Out:
# prediction     0    1
# actual
# 0           1641  444
# 1            857  460

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test_set['codigo objetivo'],prediccion)
# Out:
# 0.5088495575221239

# %%
df_agrupado=df_concatenado.groupby('Equipo')
grupo=df_agrupado.get_group('Chelsea')
grupo
# Out:
#                               Fecha    Reloj           Estadio  Asistencia  \
# 5         Saturday 8th August 2015.   5:30pm   Stamford Bridge     41232.0
# 36       Saturday 29th August 2015.   3:00pm   Stamford Bridge     41581.0
# 50    Saturday 19th September 2015.  12:45pm   Stamford Bridge     41584.0
# 76       Saturday 3rd October 2015.   5:30pm   Stamford Bridge     41642.0
# 82      Saturday 17th October 2015.   3:00pm   Stamford Bridge     41596.0
# ...                             ...      ...               ...         ...
# 6411         Sunday 7th April 2024.   5:30pm      Bramall Lane     28638.0
# 6430       Tuesday 23rd April 2024.   8:00pm  Emirates Stadium     60238.0
# 6442      Saturday 27th April 2024.   8:00pm        Villa Park     42354.0
# 6464        Saturday 11th May 2024.   5:30pm   The City Ground     29708.0
# 6468       Wednesday 15th May 2024.   7:45pm      Amex Stadium     31555.0
#
#        Equipo              Equipo Rival  Goles  Goles Rival  Posesión  \
# 5     Chelsea              Swansea City      2            2      52.0
# 36    Chelsea            Crystal Palace      1            2      63.7
# 50    Chelsea                   Arsenal      2            0      62.9
# 76    Chelsea               Southampton      1            3      60.2
# 82    Chelsea               Aston Villa      2            0      49.0
# ...       ...                       ...    ...          ...       ...
# 6411  Chelsea          Sheffield United      2            2      67.8
# 6430  Chelsea                   Arsenal      0            5      55.8
# 6442  Chelsea               Aston Villa      2            2      71.2
# 6464  Chelsea         Nottingham Forest      3            2      67.7
# 6468  Chelsea  Brighton and Hove Albion      2            1      45.3
#
#       Posesión Rival  ...  Rojas Rival  fecha_formato  Hora   Año  Codigo  \
# 5               48.0  ...            0     2015-08-08    17  2015       6
# 36              36.3  ...            0     2015-08-29    15  2015       6
# 50              37.1  ...            2     2015-09-19    12  2015       6
# 76              39.8  ...            0     2015-10-03    17  2015       6
# 82              51.0  ...            0     2015-10-17    15  2015       6
# ...              ...  ...          ...            ...   ...   ...     ...
# 6411            32.2  ...            0     2024-04-07    17  2024      29
# 6430            44.2  ...            0     2024-04-23    20  2024       7
# 6442            28.8  ...            0     2024-04-27    20  2024      11
# 6464            32.3  ...            0     2024-05-11    17  2024      32
# 6468            54.7  ...            0     2024-05-15    19  2024      24
#
#              Ganador  Codigo L_V  Codigo Rival  codigo dia  codigo objetivo
# 5             Empate           1            16           5                0
# 36    Crystal Palace           1            18           5                0
# 50           Chelsea           1             7           5                1
# 76       Southampton           1            12           5                0
# 82           Chelsea           1            11           5                1
# ...              ...         ...           ...         ...              ...
# 6411          Empate           0            29           6                0
# 6430         Arsenal           0             7           1                0
# 6442          Empate           0            11           5                0
# 6464         Chelsea           0            32           5                1
# 6468         Chelsea           0            24           2                1
#
# [324 rows x 47 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("fecha_formato")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
df_concatenado.info()

# %%
cols=['Goles','Goles Rival','Posesión', 'Posesión Rival','Tiros Totales','Tiros Rival Total','Tiros A Puerta',
      'Tiros A Puerta Rival','Tiros Fuera de Objetivo', 'Tiros Fuera de Objetivo Rival','Tiros Bloqueados',
      'Tiros Bloqueados Rival','Precisión en Pases', 'Precisión en Pases Rival','Oportunidades', 'Oportunidades Rival','Esquinas',
      'Esquinas Rival','Fuera de Juego', 'Fuera de Juego Rival','Porcentaje de Tackles Ganados', 'Porcentaje de Tackles Ganados Rival',
      'Porcentaje de Duelo Aéreo', 'Porcentaje de Duelo Aéreo Rival','Paradas', 'Paradas Rival',
      'Faltas Cometidas', 'Faltas Cometidas Rival', 'Amarillas', 'Amarillas Rival',
      'Rojas', 'Rojas Rival', ]
new_cols=[f"{c}_rolling" for c in cols]

# %%
rolling_averages(grupo,cols,new_cols)
# Out:
#                               Fecha    Reloj                    Estadio  \
# 36       Saturday 29th August 2015.   3:00pm            Stamford Bridge
# 3280  Saturday 12th September 2015.  12:45pm              Goodison Park
# 50    Saturday 19th September 2015.  12:45pm            Stamford Bridge
# 3307  Saturday 26th September 2015.   5:30pm  St James' Park, Newcastle
# 76       Saturday 3rd October 2015.   5:30pm            Stamford Bridge
# ...                             ...      ...                        ...
# 3206         Thursday 2nd May 2024.   7:30pm            Stamford Bridge
# 3213           Sunday 5th May 2024.   2:00pm            Stamford Bridge
# 6464        Saturday 11th May 2024.   5:30pm            The City Ground
# 6468       Wednesday 15th May 2024.   7:45pm               Amex Stadium
# 3230          Sunday 19th May 2024.   4:00pm            Stamford Bridge
#
#       Asistencia   Equipo              Equipo Rival  Goles  Goles Rival  \
# 36       41581.0  Chelsea            Crystal Palace      1            2
# 3280     38311.0  Chelsea                   Everton      1            3
# 50       41584.0  Chelsea                   Arsenal      2            0
# 3307     48682.0  Chelsea          Newcastle United      2            2
# 76       41642.0  Chelsea               Southampton      1            3
# ...          ...      ...                       ...    ...          ...
# 3206     39086.0  Chelsea         Tottenham Hotspur      2            0
# 3213     39295.0  Chelsea           West Ham United      5            0
# 6464     29708.0  Chelsea         Nottingham Forest      3            2
# 6468     31555.0  Chelsea  Brighton and Hove Albion      2            1
# 3230     39724.0  Chelsea               Bournemouth      2            1
#
#       Posesión  Posesión Rival  ...  Porcentaje de Duelo Aéreo_rolling  \
# 36        63.7            36.3  ...                          49.600000
# 3280      61.2            38.8  ...                          55.700000
# 50        62.9            37.1  ...                          47.333333
# 3307      64.5            35.5  ...                          50.900000
# 76        60.2            39.8  ...                          49.500000
# ...        ...             ...  ...                                ...
# 3206      37.4            62.6  ...                          49.200000
# 3213      69.4            30.6  ...                          54.100000
# 6464      67.7            32.3  ...                          56.866667
# 6468      45.3            54.7  ...                          58.633333
# 3230      61.4            38.6  ...                          49.333333
#
#       Porcentaje de Duelo Aéreo Rival_rolling  Paradas_rolling  \
# 36                                  50.400000         5.333333
# 3280                                44.300000         4.000000
# 50                                  52.666667         4.333333
# 3307                                49.100000         3.666667
# 76                                  50.500000         3.666667
# ...                                       ...              ...
# 3206                                50.800000         3.666667
# 3213                                45.900000         4.333333
# 6464                                43.133333         3.000000
# 6468                                41.366667         2.666667
# 3230                                50.666667         1.666667
#
#       Paradas Rival_rolling  Faltas Cometidas_rolling  \
# 36                 2.333333                 13.333333
# 3280               4.000000                 11.333333
# 50                 3.333333                 11.000000
# 3307               4.333333                 11.000000
# 76                 2.666667                 13.000000
# ...                     ...                       ...
# 3206               2.666667                 10.000000
# 3213               2.000000                 12.333333
# 6464               4.666667                 12.666667
# 6468               4.333333                 10.666667
# 3230               5.000000                 11.333333
#
#       Faltas Cometidas Rival_rolling  Amarillas_rolling  \
# 36                         14.666667           1.333333
# 3280                       14.333333           1.333333
# 50                         12.000000           1.333333
# 3307                       12.666667           2.000000
# 76                         11.666667           2.333333
# ...                              ...                ...
# 3206                       15.333333           2.666667
# 3213                       13.666667           2.333333
# 6464                       13.000000           2.000000
# 6468                       13.333333           1.333333
# 3230                       12.333333           2.000000
#
#       Amarillas Rival_rolling  Rojas_rolling  Rojas Rival_rolling
# 36                   3.000000       0.666667             0.000000
# 3280                 2.333333       0.333333             0.000000
# 50                   1.666667       0.333333             0.000000
# 3307                 1.666667       0.000000             0.666667
# 76                   1.666667       0.000000             0.666667
# ...                       ...            ...                  ...
# 3206                 3.000000       0.000000             0.000000
# 3213                 2.000000       0.000000             0.000000
# 6464                 2.333333       0.000000             0.000000
# 6468                 2.000000       0.000000             0.000000
# 3230                 2.333333       0.333333             0.000000
#
# [321 rows x 79 columns]

# %%
partidos_rolling=df_concatenado.groupby('Equipo').apply(lambda x: rolling_averages(x,cols,new_cols))
# Out:
# <ipython-input-37-7dd6ce284e4f>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   partidos_rolling=df_concatenado.groupby('Equipo').apply(lambda x: rolling_averages(x,cols,new_cols))

# %%
partidos_rolling
# Out:
#                                                       Fecha    Reloj  \
# Equipo
# Arsenal                 3270     Saturday 29th August 2015.  12:45pm
#                         45    Saturday 12th September 2015.   3:00pm
#                         3290  Saturday 19th September 2015.  12:45pm
#                         3301  Saturday 26th September 2015.   3:00pm
#                         78         Sunday 4th October 2015.   4:00pm
# ...                                                     ...      ...
# Wolverhampton Wanderers 3191     Wednesday 24th April 2024.   7:45pm
#                         3197      Saturday 27th April 2024.   3:00pm
#                         6452         Saturday 4th May 2024.   5:30pm
#                         3222        Saturday 11th May 2024.   3:00pm
#                         6472          Sunday 19th May 2024.   4:00pm
#
#                                                 Estadio  Asistencia  \
# Equipo
# Arsenal                 3270  St James' Park, Newcastle     50388.0
#                         45             Emirates Stadium     59963.0
#                         3290            Stamford Bridge     41584.0
#                         3301     The King Power Stadium     32047.0
#                         78             Emirates Stadium     60084.0
# ...                                                 ...         ...
# Wolverhampton Wanderers 3191                   Molineux     25541.0
#                         3197                   Molineux     31531.0
#                         6452             Etihad Stadium     52439.0
#                         3222                   Molineux     31424.0
#                         6472                    Anfield     60059.0
#
#                                                Equipo       Equipo Rival  \
# Equipo
# Arsenal                 3270                  Arsenal   Newcastle United
#                         45                    Arsenal         Stoke City
#                         3290                  Arsenal            Chelsea
#                         3301                  Arsenal     Leicester City
#                         78                    Arsenal  Manchester United
# ...                                               ...                ...
# Wolverhampton Wanderers 3191  Wolverhampton Wanderers        Bournemouth
#                         3197  Wolverhampton Wanderers         Luton Town
#                         6452  Wolverhampton Wanderers    Manchester City
#                         3222  Wolverhampton Wanderers     Crystal Palace
#                         6472  Wolverhampton Wanderers          Liverpool
#
#                               Goles  Goles Rival  Posesión  Posesión Rival  \
# Equipo
# Arsenal                 3270      1            0      73.7            26.3
#                         45        2            0      67.6            32.4
#                         3290      0            2      37.1            62.9
#                         3301      5            2      58.0            42.0
#                         78        3            0      37.8            62.2
# ...                             ...          ...       ...             ...
# Wolverhampton Wanderers 3191      0            1      62.8            37.2
#                         3197      2            1      57.8            42.2
#                         6452      1            5      42.1            57.9
#                         3222      1            3      61.7            38.3
#                         6472      0            2      32.6            67.4
#
#                               ...  Porcentaje de Duelo Aéreo_rolling  \
# Equipo                        ...
# Arsenal                 3270  ...                          53.133333
#                         45    ...                          48.900000
#                         3290  ...                          51.333333
#                         3301  ...                          49.400000
#                         78    ...                          54.633333
# ...                           ...                                ...
# Wolverhampton Wanderers 3191  ...                          33.600000
#                         3197  ...                          38.966667
#                         6452  ...                          43.366667
#                         3222  ...                          38.966667
#                         6472  ...                          35.833333
#
#                               Porcentaje de Duelo Aéreo Rival_rolling  \
# Equipo
# Arsenal                 3270                                46.866667
#                         45                                  51.100000
#                         3290                                48.666667
#                         3301                                50.600000
#                         78                                  45.366667
# ...                                                               ...
# Wolverhampton Wanderers 3191                                66.400000
#                         3197                                61.033333
#                         6452                                56.633333
#                         3222                                61.033333
#                         6472                                64.166667
#
#                               Paradas_rolling  Paradas Rival_rolling  \
# Equipo
# Arsenal                 3270         4.333333               5.333333
#                         45           3.666667               6.333333
#                         3290         3.666667               8.000000
#                         3301         2.666667               7.000000
#                         78           4.333333               6.000000
# ...                                       ...                    ...
# Wolverhampton Wanderers 3191         5.333333               3.333333
#                         3197         6.333333               2.666667
#                         6452         5.666667               3.333333
#                         3222         5.666667               2.333333
#                         6472         4.000000               3.333333
#
#                               Faltas Cometidas_rolling  \
# Equipo
# Arsenal                 3270                  8.666667
#                         45                    7.333333
#                         3290                  5.333333
#                         3301                  8.333333
#                         78                    9.666667
# ...                                                ...
# Wolverhampton Wanderers 3191                 13.000000
#                         3197                 11.333333
#                         6452                 12.666667
#                         3222                 13.666667
#                         6472                 14.666667
#
#                               Faltas Cometidas Rival_rolling  \
# Equipo
# Arsenal                 3270                       12.000000
#                         45                         14.000000
#                         3290                       13.666667
#                         3301                       13.333333
#                         78                         11.333333
# ...                                                      ...
# Wolverhampton Wanderers 3191                       10.333333
#                         3197                       13.666667
#                         6452                       13.333333
#                         3222                       11.666667
#                         6472                       10.000000
#
#                               Amarillas_rolling  Amarillas Rival_rolling  \
# Equipo
# Arsenal                 3270           1.000000                 2.666667
#                         45             1.000000                 3.666667
#                         3290           1.000000                 3.666667
#                         3301           1.333333                 3.333333
#                         78             1.333333                 1.666667
# ...                                         ...                      ...
# Wolverhampton Wanderers 3191           3.666667                 2.000000
#                         3197           3.333333                 1.666667
#                         6452           3.333333                 1.333333
#                         3222           3.666667                 0.666667
#                         6472           3.333333                 1.000000
#
#                               Rojas_rolling  Rojas Rival_rolling
# Equipo
# Arsenal                 3270       0.000000             0.000000
#                         45         0.000000             0.333333
#                         3290       0.000000             0.333333
#                         3301       0.666667             0.333333
#                         78         0.666667             0.000000
# ...                                     ...                  ...
# Wolverhampton Wanderers 3191       0.000000             0.000000
#                         3197       0.000000             0.333333
#                         6452       0.000000             0.333333
#                         3222       0.000000             0.333333
#                         6472       0.000000             0.333333
#
# [6381 rows x 79 columns]

# %%
partidos_rolling=partidos_rolling.droplevel('Equipo')

# %%
partidos_rolling=partidos_rolling.reset_index()
partidos_rolling
# Out:
#       index                          Fecha    Reloj  \
# 0      3270     Saturday 29th August 2015.  12:45pm
# 1        45  Saturday 12th September 2015.   3:00pm
# 2      3290  Saturday 19th September 2015.  12:45pm
# 3      3301  Saturday 26th September 2015.   3:00pm
# 4        78       Sunday 4th October 2015.   4:00pm
# ...     ...                            ...      ...
# 6376   3191     Wednesday 24th April 2024.   7:45pm
# 6377   3197      Saturday 27th April 2024.   3:00pm
# 6378   6452         Saturday 4th May 2024.   5:30pm
# 6379   3222        Saturday 11th May 2024.   3:00pm
# 6380   6472          Sunday 19th May 2024.   4:00pm
#
#                         Estadio  Asistencia                   Equipo  \
# 0     St James' Park, Newcastle     50388.0                  Arsenal
# 1              Emirates Stadium     59963.0                  Arsenal
# 2               Stamford Bridge     41584.0                  Arsenal
# 3        The King Power Stadium     32047.0                  Arsenal
# 4              Emirates Stadium     60084.0                  Arsenal
# ...                         ...         ...                      ...
# 6376                   Molineux     25541.0  Wolverhampton Wanderers
# 6377                   Molineux     31531.0  Wolverhampton Wanderers
# 6378             Etihad Stadium     52439.0  Wolverhampton Wanderers
# 6379                   Molineux     31424.0  Wolverhampton Wanderers
# 6380                    Anfield     60059.0  Wolverhampton Wanderers
#
#            Equipo Rival  Goles  Goles Rival  Posesión  ...  \
# 0      Newcastle United      1            0      73.7  ...
# 1            Stoke City      2            0      67.6  ...
# 2               Chelsea      0            2      37.1  ...
# 3        Leicester City      5            2      58.0  ...
# 4     Manchester United      3            0      37.8  ...
# ...                 ...    ...          ...       ...  ...
# 6376        Bournemouth      0            1      62.8  ...
# 6377         Luton Town      2            1      57.8  ...
# 6378    Manchester City      1            5      42.1  ...
# 6379     Crystal Palace      1            3      61.7  ...
# 6380          Liverpool      0            2      32.6  ...
#
#       Porcentaje de Duelo Aéreo_rolling  \
# 0                             53.133333
# 1                             48.900000
# 2                             51.333333
# 3                             49.400000
# 4                             54.633333
# ...                                 ...
# 6376                          33.600000
# 6377                          38.966667
# 6378                          43.366667
# 6379                          38.966667
# 6380                          35.833333
#
#       Porcentaje de Duelo Aéreo Rival_rolling  Paradas_rolling  \
# 0                                   46.866667         4.333333
# 1                                   51.100000         3.666667
# 2                                   48.666667         3.666667
# 3                                   50.600000         2.666667
# 4                                   45.366667         4.333333
# ...                                       ...              ...
# 6376                                66.400000         5.333333
# 6377                                61.033333         6.333333
# 6378                                56.633333         5.666667
# 6379                                61.033333         5.666667
# 6380                                64.166667         4.000000
#
#       Paradas Rival_rolling  Faltas Cometidas_rolling  \
# 0                  5.333333                  8.666667
# 1                  6.333333                  7.333333
# 2                  8.000000                  5.333333
# 3                  7.000000                  8.333333
# 4                  6.000000                  9.666667
# ...                     ...                       ...
# 6376               3.333333                 13.000000
# 6377               2.666667                 11.333333
# 6378               3.333333                 12.666667
# 6379               2.333333                 13.666667
# 6380               3.333333                 14.666667
#
#       Faltas Cometidas Rival_rolling  Amarillas_rolling  \
# 0                          12.000000           1.000000
# 1                          14.000000           1.000000
# 2                          13.666667           1.000000
# 3                          13.333333           1.333333
# 4                          11.333333           1.333333
# ...                              ...                ...
# 6376                       10.333333           3.666667
# 6377                       13.666667           3.333333
# 6378                       13.333333           3.333333
# 6379                       11.666667           3.666667
# 6380                       10.000000           3.333333
#
#       Amarillas Rival_rolling  Rojas_rolling  Rojas Rival_rolling
# 0                    2.666667       0.000000             0.000000
# 1                    3.666667       0.000000             0.333333
# 2                    3.666667       0.000000             0.333333
# 3                    3.333333       0.666667             0.333333
# 4                    1.666667       0.666667             0.000000
# ...                       ...            ...                  ...
# 6376                 2.000000       0.000000             0.000000
# 6377                 1.666667       0.000000             0.333333
# 6378                 1.333333       0.000000             0.333333
# 6379                 0.666667       0.000000             0.333333
# 6380                 1.000000       0.000000             0.333333
#
# [6381 rows x 80 columns]

# %%
partidos_rolling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6381 entries, 0 to 6380
# Data columns (total 80 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   index                                        6381 non-null   int64
#  1   Fecha                                        6381 non-null   object
#  2   Reloj                                        6381 non-null   object
#  3   Estadio                                      6381 non-null   object
#  4   Asistencia                                   6381 non-null   float64
#  5   Equipo                                       6381 non-null   object
#  6   Equipo Rival                                 6381 non-null   object
#  7   Goles                                        6381 non-null   int64
#  8   Goles Rival                                  6381 non-null   int64
#  9   Posesión                                     6381 non-null   float64
#  10  Posesión Rival                               6381 non-null   float64
#  11  Tiros Totales                                6381 non-null   int64
#  12  Tiros Rival Total                            6381 non-null   int64
#  13  Tiros A Puerta                               6381 non-null   int64
#  14  Tiros A Puerta Rival                         6381 non-null   int64
#  15  Tiros Fuera de Objetivo                      6381 non-null   int64
#  16  Tiros Fuera de Objetivo Rival                6381 non-null   int64
#  17  Tiros Bloqueados                             6381 non-null   int64
#  18  Tiros Bloqueados Rival                       6381 non-null   int64
#  19  Precisión en Pases                           6381 non-null   float64
#  20  Precisión en Pases Rival                     6381 non-null   float64
#  21  Oportunidades                                6381 non-null   int64
#  22  Oportunidades Rival                          6381 non-null   int64
#  23  Esquinas                                     6381 non-null   int64
#  24  Esquinas Rival                               6381 non-null   int64
#  25  Fuera de Juego                               6381 non-null   int64
#  26  Fuera de Juego Rival                         6381 non-null   int64
#  27  Porcentaje de Tackles Ganados                6381 non-null   float64
#  28  Porcentaje de Tackles Ganados Rival          6381 non-null   float64
#  29  Porcentaje de Duelo Aéreo                    6381 non-null   float64
#  30  Porcentaje de Duelo Aéreo Rival              6381 non-null   float64
#  31  Paradas                                      6381 non-null   int64
#  32  Paradas Rival                                6381 non-null   int64
#  33  Faltas Cometidas                             6381 non-null   int64
#  34  Faltas Cometidas Rival                       6381 non-null   int64
#  35  Amarillas                                    6381 non-null   int64
#  36  Amarillas Rival                              6381 non-null   int64
#  37  Rojas                                        6381 non-null   int64
#  38  Rojas Rival                                  6381 non-null   int64
#  39  fecha_formato                                6381 non-null   datetime64[ns]
#  40  Hora                                         6381 non-null   int64
#  41  Año                                          6381 non-null   int64
#  42  Codigo                                       6381 non-null   int64
#  43  Ganador                                      6381 non-null   object
#  44  Codigo L_V                                   6381 non-null   int64
#  45  Codigo Rival                                 6381 non-null   int64
#  46  codigo dia                                   6381 non-null   int32
#  47  codigo objetivo                              6381 non-null   int64
#  48  Goles_rolling                                6381 non-null   float64
#  49  Goles Rival_rolling                          6381 non-null   float64
#  50  Posesión_rolling                             6381 non-null   float64
#  51  Posesión Rival_rolling                       6381 non-null   float64
#  52  Tiros Totales_rolling                        6381 non-null   float64
#  53  Tiros Rival Total_rolling                    6381 non-null   float64
#  54  Tiros A Puerta_rolling                       6381 non-null   float64
#  55  Tiros A Puerta Rival_rolling                 6381 non-null   float64
#  56  Tiros Fuera de Objetivo_rolling              6381 non-null   float64
#  57  Tiros Fuera de Objetivo Rival_rolling        6381 non-null   float64
#  58  Tiros Bloqueados_rolling                     6381 non-null   float64
#  59  Tiros Bloqueados Rival_rolling               6381 non-null   float64
#  60  Precisión en Pases_rolling                   6381 non-null   float64
#  61  Precisión en Pases Rival_rolling             6381 non-null   float64
#  62  Oportunidades_rolling                        6381 non-null   float64
#  63  Oportunidades Rival_rolling                  6381 non-null   float64
#  64  Esquinas_rolling                             6381 non-null   float64
#  65  Esquinas Rival_rolling                       6381 non-null   float64
#  66  Fuera de Juego_rolling                       6381 non-null   float64
#  67  Fuera de Juego Rival_rolling                 6381 non-null   float64
#  68  Porcentaje de Tackles Ganados_rolling        6381 non-null   float64
#  69  Porcentaje de Tackles Ganados Rival_rolling  6381 non-null   float64
#  70  Porcentaje de Duelo Aéreo_rolling            6381 non-null   float64
#  71  Porcentaje de Duelo Aéreo Rival_rolling      6381 non-null   float64
#  72  Paradas_rolling                              6381 non-null   float64
#  73  Paradas Rival_rolling                        6381 non-null   float64
#  74  Faltas Cometidas_rolling                     6381 non-null   float64
#  75  Faltas Cometidas Rival_rolling               6381 non-null   float64
#  76  Amarillas_rolling                            6381 non-null   float64
#  77  Amarillas Rival_rolling                      6381 non-null   float64
#  78  Rojas_rolling                                6381 non-null   float64
#  79  Rojas Rival_rolling                          6381 non-null   float64
# dtypes: datetime64[ns](1), float64(41), int32(1), int64(31), object(6)
# memory usage: 3.9+ MB

# %%
def hacer_predicciones(data,predecir):
  train_set = data[data['Año'] < 2022]
  test_set = data[data['Año'] >= 2022]
  rf.fit(train_set[predecir],train_set['codigo objetivo'])
  prediccion=rf.predict(test_set[predecir])
  combinacion=pd.DataFrame(dict(actual=test_set['codigo objetivo'],prediction=prediccion),index=test_set.index)
  precision_score=accuracy_score(test_set['codigo objetivo'],prediccion)
  return  combinacion, precision_score

# %%
combinacion,precision_score=hacer_predicciones(partidos_rolling, predecir + new_cols)

# %%
predecir
# Out:
# ['Codigo L_V', 'Codigo Rival', 'Hora', 'codigo dia']

# %%
precision_score
# Out:
# 0.6572327044025157

# %%
combinacion
# Out:
#       actual  prediction
# 226        0           1
# 227        0           0
# 228        1           1
# 229        1           0
# 230        1           1
# ...      ...         ...
# 6376       0           0
# 6377       1           0
# 6378       0           0
# 6379       0           0
# 6380       0           0
#
# [1908 rows x 2 columns]

# %%
combinacion = combinacion.merge(partidos_rolling[['Fecha','Equipo','Equipo Rival','Goles','Goles Rival','Ganador','codigo objetivo']], left_index=True, right_index=True)

# %%
combinacion
# Out:
#       actual  prediction                         Fecha  \
# 226        0           1    Saturday 1st January 2022.
# 227        0           0     Sunday 23rd January 2022.
# 228        1           1  Thursday 10th February 2022.
# 229        1           0  Saturday 19th February 2022.
# 230        1           1  Thursday 24th February 2022.
# ...      ...         ...                           ...
# 6376       0           0    Wednesday 24th April 2024.
# 6377       1           0     Saturday 27th April 2024.
# 6378       0           0        Saturday 4th May 2024.
# 6379       0           0       Saturday 11th May 2024.
# 6380       0           0         Sunday 19th May 2024.
#
#                        Equipo             Equipo Rival  Goles  Goles Rival  \
# 226                   Arsenal          Manchester City      1            2
# 227                   Arsenal                  Burnley      0            0
# 228                   Arsenal  Wolverhampton Wanderers      1            0
# 229                   Arsenal                Brentford      2            1
# 230                   Arsenal  Wolverhampton Wanderers      2            1
# ...                       ...                      ...    ...          ...
# 6376  Wolverhampton Wanderers              Bournemouth      0            1
# 6377  Wolverhampton Wanderers               Luton Town      2            1
# 6378  Wolverhampton Wanderers          Manchester City      1            5
# 6379  Wolverhampton Wanderers           Crystal Palace      1            3
# 6380  Wolverhampton Wanderers                Liverpool      0            2
#
#                       Ganador  codigo objetivo
# 226           Manchester City                0
# 227                    Empate                0
# 228                   Arsenal                1
# 229                   Arsenal                1
# 230                   Arsenal                1
# ...                       ...              ...
# 6376              Bournemouth                0
# 6377  Wolverhampton Wanderers                1
# 6378          Manchester City                0
# 6379           Crystal Palace                0
# 6380                Liverpool                0
#
# [1908 rows x 9 columns]

# %%
filtro = df_concatenado[df_concatenado['Fecha'] == 'Sunday 30th December 2018.']
filtro
# Out:
#                            Fecha    Reloj             Estadio  Asistencia  \
# 1336  Sunday 30th December 2018.  12:00pm       Selhurst Park     25781.0
# 1337  Sunday 30th December 2018.   2:15pm           Turf Moor     20933.0
# 1338  Sunday 30th December 2018.   2:15pm  St. Mary's Stadium     31381.0
# 1339  Sunday 30th December 2018.   4:30pm        Old Trafford     74556.0
# 4576  Sunday 30th December 2018.  12:00pm       Selhurst Park     25781.0
# 4577  Sunday 30th December 2018.   2:15pm           Turf Moor     20933.0
# 4578  Sunday 30th December 2018.   2:15pm  St. Mary's Stadium     31381.0
# 4579  Sunday 30th December 2018.   4:30pm        Old Trafford     74556.0
#
#                  Equipo       Equipo Rival  Goles  Goles Rival  Posesión  \
# 1336     Crystal Palace            Chelsea      0            1      34.2
# 1337            Burnley    West Ham United      2            0      43.0
# 1338        Southampton    Manchester City      1            3      23.4
# 1339  Manchester United        Bournemouth      4            1      64.9
# 4576            Chelsea     Crystal Palace      1            0      65.8
# 4577    West Ham United            Burnley      0            2      57.0
# 4578    Manchester City        Southampton      3            1      76.6
# 4579        Bournemouth  Manchester United      1            4      35.1
#
#       Posesión Rival  ...  Rojas Rival  fecha_formato  Hora   Año  Codigo  \
# 1336            65.8  ...            0     2018-12-30    12  2018      18
# 1337            57.0  ...            0     2018-12-30    14  2018      23
# 1338            76.6  ...            0     2018-12-30    14  2018      12
# 1339            35.1  ...            0     2018-12-30    16  2018       1
# 4576            34.2  ...            0     2018-12-30    12  2018      18
# 4577            43.0  ...            0     2018-12-30    14  2018      23
# 4578            23.4  ...            1     2018-12-30    14  2018      12
# 4579            64.9  ...            1     2018-12-30    16  2018       1
#
#                 Ganador  Codigo L_V  Codigo Rival  codigo dia  codigo objetivo
# 1336            Chelsea           1             6           6                0
# 1337            Burnley           1            13           6                1
# 1338    Manchester City           1            19           6                0
# 1339  Manchester United           1             5           6                1
# 4576            Chelsea           0            18           6                1
# 4577            Burnley           0            23           6                0
# 4578    Manchester City           0            12           6                1
# 4579  Manchester United           0             1           6                0
#
# [8 rows x 47 columns]

# %%
fusion = combinacion.merge(combinacion, left_on=["Fecha", "Equipo"], right_on=["Fecha", "Equipo Rival"])
fusion
# Out:
#       actual_x  prediction_x                         Fecha  \
# 0            0             1    Saturday 1st January 2022.
# 1            0             0     Sunday 23rd January 2022.
# 2            1             1  Thursday 10th February 2022.
# 3            1             0  Saturday 19th February 2022.
# 4            1             1  Thursday 24th February 2022.
# ...        ...           ...                           ...
# 1897         0             0    Wednesday 24th April 2024.
# 1898         1             0     Saturday 27th April 2024.
# 1899         0             0        Saturday 4th May 2024.
# 1900         0             0       Saturday 11th May 2024.
# 1901         0             0         Sunday 19th May 2024.
#
#                      Equipo_x           Equipo Rival_x  Goles_x  \
# 0                     Arsenal          Manchester City        1
# 1                     Arsenal                  Burnley        0
# 2                     Arsenal  Wolverhampton Wanderers        1
# 3                     Arsenal                Brentford        2
# 4                     Arsenal  Wolverhampton Wanderers        2
# ...                       ...                      ...      ...
# 1897  Wolverhampton Wanderers              Bournemouth        0
# 1898  Wolverhampton Wanderers               Luton Town        2
# 1899  Wolverhampton Wanderers          Manchester City        1
# 1900  Wolverhampton Wanderers           Crystal Palace        1
# 1901  Wolverhampton Wanderers                Liverpool        0
#
#       Goles Rival_x                Ganador_x  codigo objetivo_x  actual_y  \
# 0                 2          Manchester City                  0         1
# 1                 0                   Empate                  0         0
# 2                 0                  Arsenal                  1         0
# 3                 1                  Arsenal                  1         0
# 4                 1                  Arsenal                  1         0
# ...             ...                      ...                ...       ...
# 1897              1              Bournemouth                  0         1
# 1898              1  Wolverhampton Wanderers                  1         0
# 1899              5          Manchester City                  0         1
# 1900              3           Crystal Palace                  0         1
# 1901              2                Liverpool                  0         1
#
#       prediction_y                 Equipo_y           Equipo Rival_y  Goles_y  \
# 0                1          Manchester City                  Arsenal        2
# 1                0                  Burnley                  Arsenal        0
# 2                0  Wolverhampton Wanderers                  Arsenal        0
# 3                0                Brentford                  Arsenal        1
# 4                0  Wolverhampton Wanderers                  Arsenal        1
# ...            ...                      ...                      ...      ...
# 1897             0              Bournemouth  Wolverhampton Wanderers        1
# 1898             0               Luton Town  Wolverhampton Wanderers        1
# 1899             1          Manchester City  Wolverhampton Wanderers        5
# 1900             0           Crystal Palace  Wolverhampton Wanderers        3
# 1901             1                Liverpool  Wolverhampton Wanderers        2
#
#       Goles Rival_y                Ganador_y  codigo objetivo_y
# 0                 1          Manchester City                  1
# 1                 0                   Empate                  0
# 2                 1                  Arsenal                  0
# 3                 2                  Arsenal                  0
# 4                 2                  Arsenal                  0
# ...             ...                      ...                ...
# 1897              0              Bournemouth                  1
# 1898              2  Wolverhampton Wanderers                  0
# 1899              1          Manchester City                  1
# 1900              1           Crystal Palace                  1
# 1901              0                Liverpool                  1
#
# [1902 rows x 17 columns]

# %%
fusion[(fusion["prediction_x"] == 1) & (fusion["prediction_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    240
# 0    132
# Name: count, dtype: int64

# %%
prec=267/400
print(prec)
# Out:
# 0.6675

# %% [markdown]
# # Modelo 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
X = df_concatenado[['Goles','Tiros A Puerta', 'Oportunidades', 'Amarillas', 'Rojas', 'Posesión', 'Paradas']]
y = df_concatenado['codigo objetivo']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=77)

# %%
x_testeado=X_test

# %%
y_testeado=y_test

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.31660436,  0.63151914,  0.44048943, ..., -0.24107538,
#         -0.00525102, -1.46573611],
#        [-1.0945661 ,  0.23792601, -1.05506449, ..., -0.24107538,
#          0.47159047, -0.46353849],
#        [-0.31660436, -0.54926026,  0.44048943, ..., -0.24107538,
#         -1.33415353,  2.04195555],
#        ...,
#        [-0.31660436, -0.15566713,  0.44048943, ..., -0.24107538,
#          0.91716366, -1.46573611],
#        [-1.0945661 , -0.54926026, -1.05506449, ..., -0.24107538,
#         -0.23976323,  1.03975793],
#        [-1.0945661 , -1.33644653, -0.30728753, ..., -0.24107538,
#         -1.59211696, -1.46573611]])

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_train_df = pd.DataFrame(X_train, columns=['Goles', 'Tiros A Puerta', 'Oportunidades', 'Amarillas', 'Rojas', 'Posesión', 'Paradas'])
y_train_series = pd.Series(y_train)

# Mostrar las primeras filas
print("Muestras de X_train:")
X_train_df
# Out:
# Muestras de X_train:
#          Goles  Tiros A Puerta  Oportunidades  Amarillas     Rojas  Posesión  \
# 0    -0.316604        0.631519       0.440489   0.243132 -0.241075 -0.005251
# 1    -1.094566        0.237926      -1.055064   0.243132 -0.241075  0.471590
# 2    -0.316604       -0.549260       0.440489   0.243132 -0.241075 -1.334154
# 3     0.461357        1.025112       0.440489  -0.542931 -0.241075  1.909932
# 4    -0.316604       -0.549260      -1.055064   1.029195 -0.241075  0.033834
# ...        ...             ...            ...        ...       ...       ...
# 4531 -0.316604        0.237926      -1.055064   0.243132 -0.241075  0.956249
# 4532 -0.316604       -0.942853      -1.055064   1.029195  3.869894 -1.662471
# 4533 -0.316604       -0.155667       0.440489   1.815259 -0.241075  0.917164
# 4534 -1.094566       -0.549260      -1.055064  -0.542931 -0.241075 -0.239763
# 4535 -1.094566       -1.336447      -0.307288   1.029195 -0.241075 -1.592117
#
#        Paradas
# 0    -1.465736
# 1    -0.463538
# 2     2.041956
# 3     0.037560
# 4     1.039758
# ...        ...
# 4531  0.037560
# 4532 -1.465736
# 4533 -1.465736
# 4534  1.039758
# 4535 -1.465736
#
# [4536 rows x 7 columns]

# %%
print("\nMuestras de y_train:")
y_train_series
# Out:
# Muestras de y_train:
# 2705    1
# 3709    0
# 6400    0
# 1045    1
# 516     0
#        ..
# 1317    0
# 2283    0
# 2004    1
# 3668    0
# 607     0
# Name: codigo objetivo, Length: 4536, dtype: int64

# %%
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Matriz de confusión:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8050411522633745
# Matriz de confusión:
#  [[1024  192]
#  [ 187  541]]

# %% [markdown]
# Verdadera Positiva (TP): Casos en los que el modelo predijo correctamente la clase positiva.
# Verdadera Negativa (TN): Casos en los que el modelo predijo correctamente la clase negativa.
# Falsa Positiva (FP): Casos en los que el modelo predijo la clase positiva, pero la verdadera clase era negativa (también conocido como error tipo I).
# Falsa Negativa (FN): Casos en los que el modelo predijo la clase negativa, pero la verdadera clase era positiva (error tipo II).

# %%
#  Predicción Positiva       |      Predicción Negativa
#Verdadera Positiva (TP)     |     Verdadera Negativa (TN)
#Falsa Positiva (FP)         |     Falsa Negativa (FN)

# %%
from typing import Container
results_df = pd.DataFrame({
    'Predicciones': y_pred,
    'Target Real': y_test
})



results_df['Acierto'] = results_df['Predicciones'] == results_df['Target Real']

contar = results_df['Acierto'].sum()

contar
# Out:
# 1565

# %%
results_df
# Out:
#       Predicciones  Target Real  Acierto
# 5279             0            0     True
# 5676             0            0     True
# 5587             0            0     True
# 5269             0            0     True
# 4488             0            0     True
# ...            ...          ...      ...
# 1751             1            1     True
# 66               1            1     True
# 3810             0            0     True
# 6049             0            0     True
# 4032             0            0     True
#
# [1944 rows x 3 columns]

# %%
equipos = df_concatenado[['Equipo', 'Equipo Rival', 'Goles', 'Goles Rival', 'codigo objetivo']]

# %%
cucu_df = pd.merge(equipos, results_df, left_index=True, right_index=True)

# %%
cucu_df
# Out:
#                  Equipo              Equipo Rival  Goles  Goles Rival  \
# 7      Newcastle United               Southampton      2            2
# 12      West Ham United            Leicester City      1            2
# 15         Swansea City          Newcastle United      2            0
# 28              Everton           Manchester City      0            2
# 34           Stoke City      West Bromwich Albion      0            1
# ...                 ...                       ...    ...          ...
# 6468            Chelsea  Brighton and Hove Albion      2            1
# 6473  Nottingham Forest                   Burnley      2            1
# 6477             Fulham                Luton Town      4            2
# 6478  Manchester United  Brighton and Hove Albion      2            0
# 6479            Everton                   Arsenal      1            2
#
#       codigo objetivo  Predicciones  Target Real  Acierto
# 7                   0             1            0    False
# 12                  0             0            0     True
# 15                  1             1            1     True
# 28                  0             0            0     True
# 34                  0             0            0     True
# ...               ...           ...          ...      ...
# 6468                1             0            1    False
# 6473                1             1            1     True
# 6477                1             1            1     True
# 6478                1             1            1     True
# 6479                0             0            0     True
#
# [1944 rows x 8 columns]

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8050411522633745
