# %% [markdown]
# <a href="https://colab.research.google.com/github/ivthdim/fluffy-guacamole/blob/main/Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_listings = pd.read_csv('listings.csv')


print(df_listings.head())
# Out:
#       id                                              name  host_id host_name  \
# 0  35797                                       Villa Dante   153786      Dici
# 1  44616                                      Condesa Haus   196253  Fernando
# 2  56074              Great space in historical San Rafael   265650     Maris
# 3  67703                 2 bedroom apt. deco bldg, Condesa   334451  Nicholas
# 4  70644  Beautiful light Studio Coyoacan- full equipped !   212109    Trisha
#
#    neighbourhood_group          neighbourhood  latitude  longitude  \
# 0                  NaN  Cuajimalpa de Morelos  19.38283  -99.27178
# 1                  NaN             Cuauhtémoc  19.41162  -99.17794
# 2                  NaN             Cuauhtémoc  19.43977  -99.15605
# 3                  NaN             Cuauhtémoc  19.41152  -99.16857
# 4                  NaN               Coyoacán  19.35448  -99.16217
#
#          room_type   price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26067 entries, 0 to 26066
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              26067 non-null  int64
#  1   name                            26067 non-null  object
#  2   host_id                         26067 non-null  int64
#  3   host_name                       26062 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   26067 non-null  object
#  6   latitude                        26067 non-null  float64
#  7   longitude                       26067 non-null  float64
#  8   room_type                       26067 non-null  object
#  9   price                           22068 non-null  float64
#  10  minimum_nights                  26067 non-null  int64
#  11  number_of_reviews               26067 non-null  int64
# ...

# %%
df_listing= df_listings.drop(['number_of_reviews', 'last_review','reviews_per_month','calculated_host_listings_count','availability_365','number_of_reviews_ltm'], axis=1)

# %%
df_listings2 = pd.read_csv('listings 2.csv')

# %%
df_listings2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26067 entries, 0 to 26066
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            26067 non-null  int64
#  1   listing_url                                   26067 non-null  object
#  2   scrape_id                                     26067 non-null  int64
#  3   last_scraped                                  26067 non-null  object
#  4   source                                        26067 non-null  object
#  5   name                                          26067 non-null  object
#  6   description                                   25300 non-null  object
#  7   neighborhood_overview                         14391 non-null  object
#  8   picture_url                                   26067 non-null  object
# ...

# %%
df_listings_ordenado=df_listings.sort_values(by='id',ascending=True)
df_listings_ordenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26067 entries, 0 to 26066
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              26067 non-null  int64
#  1   name                            26067 non-null  object
#  2   host_id                         26067 non-null  int64
#  3   host_name                       26062 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   26067 non-null  object
#  6   latitude                        26067 non-null  float64
#  7   longitude                       26067 non-null  float64
#  8   room_type                       26067 non-null  object
#  9   price                           22068 non-null  float64
#  10  minimum_nights                  26067 non-null  int64
#  11  number_of_reviews               26067 non-null  int64
# ...

# %%
df_listings2_ordenado=df_listings2.sort_values(by='id',ascending=True)
df_listings2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26067 entries, 0 to 26066
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            26067 non-null  int64
#  1   listing_url                                   26067 non-null  object
#  2   scrape_id                                     26067 non-null  int64
#  3   last_scraped                                  26067 non-null  object
#  4   source                                        26067 non-null  object
#  5   name                                          26067 non-null  object
#  6   description                                   25300 non-null  object
#  7   neighborhood_overview                         14391 non-null  object
#  8   picture_url                                   26067 non-null  object
# ...

# %%
df_listings_merged = pd.merge(df_listings, df_listings2, on='id')

# %%
df_listings_merged
# Out:
#                         id                                             name_x  \
# 0                    35797                                        Villa Dante
# 1                    44616                                       Condesa Haus
# 2                    56074               Great space in historical San Rafael
# 3                    67703                  2 bedroom apt. deco bldg, Condesa
# 4                    70644   Beautiful light Studio Coyoacan- full equipped !
# ...                    ...                                                ...
# 26062  1379327529227113949                   Cama en Dorm mixto de 4 personas
# 26063  1379338090263773362  loft #307 excelente ubicación ideal para descanso
# 26064  1379781424660291699                            Cozy room in Roma Norte
# 26065  1379807014531191212   Stylish suite w private terrace close to Polanco
# 26066  1379814270520534429                     Depto. en el corazón de Roma N
#
# ...

# %%
df_listings_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26067 entries, 0 to 26066
# Data columns (total 96 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            26067 non-null  int64
#  1   name_x                                        26067 non-null  object
#  2   host_id_x                                     26067 non-null  int64
#  3   host_name_x                                   26062 non-null  object
#  4   neighbourhood_group                           0 non-null      float64
#  5   neighbourhood_x                               26067 non-null  object
#  6   latitude_x                                    26067 non-null  float64
#  7   longitude_x                                   26067 non-null  float64
#  8   room_type_x                                   26067 non-null  object
# ...
